# %% [markdown]
# # 📝 Session 1 — Exercises
# ## Basics of Data Science — Module 1
#
# **Instructions:** Complete all exercises. Write your code in the provided cells.
# There are 5 exercises, ranging from basic to challenging.
#
# ---
#
# ⚠️ **Do not look at the lecture notebook** while solving — try from memory first!

# %% [markdown]
# ### Exercise 1 — List Operations (Basic)
#
# You have a list of temperatures (in Celsius) recorded over a week:
# ```python
# temps_celsius = [22, 28, 19, 31, 25, 17, 30]
# ```
#
# **Tasks:**
# 1. Print the maximum and minimum temperatures
# 2. Compute the average temperature
# 3. Convert all temperatures to Fahrenheit using a list comprehension
#    - Formula: `F = (C × 9/5) + 32`
# 4. Print only the temperatures above 25°C

# %%
# Your code here
temps_celsius = [22, 28, 19, 31, 25, 17, 30]

# 1. Max and min

# 2. Average

# 3. Convert to Fahrenheit

# 4. Temperatures above 25

# %% [markdown]
# ---
#
# ### Exercise 2 — Dictionary Operations (Basic)
#
# Create a dictionary to represent a movie with the following information:
# - Title: `'Inception'`
# - Director: `'Christopher Nolan'`
# - Year: `2010`
# - Rating: `8.8`
# - Genres: `['Action', 'Sci-Fi', 'Thriller']`
#
# **Tasks:**
# 1. Create the dictionary
# 2. Print the title and rating
# 3. Add a new key `'watched'` with value `True`
# 4. Print all genres in uppercase using a list comprehension
# 5. Safely get the value for key `'budget'` (doesn't exist) — use `.get()` with a default

# %%
# Your code here

# 1. Create the dictionary

# 2. Print title and rating

# 3. Add 'watched'

# 4. Genres in uppercase

# 5. Safe get 'budget'

# %% [markdown]
# ---
#
# ### Exercise 3 — Functions (Intermediate)
#
# Write a function called `analyze_list` that takes a list of numbers and returns a **dictionary** with the following statistics:
# - `count`: number of elements
# - `total`: sum of all elements
# - `mean`: arithmetic average
# - `minimum`: smallest value
# - `maximum`: largest value
# - `range`: max - min
#
# Then test your function with: `[15, 22, 8, 41, 7, 33, 19, 26, 12]`
#
# Expected output (approximately):
# ```
# count: 9, total: 183, mean: 20.33, min: 7, max: 41, range: 34
# ```

# %%
# Write the analyze_list function

def analyze_list(numbers):
    # Your implementation here
    pass

# Test it
test_data = [15, 22, 8, 41, 7, 33, 19, 26, 12]
result = analyze_list(test_data)
print(result)

# %% [markdown]
# ---
#
# ### Exercise 4 — Working with a Dataset (Intermediate)
#
# You have a list of dictionaries representing employees:
# ```python
# employees = [
#     {'name': 'Alice', 'dept': 'Engineering', 'salary': 95000, 'years': 5},
#     {'name': 'Bob',   'dept': 'Marketing',   'salary': 72000, 'years': 3},
#     {'name': 'Carol', 'dept': 'Engineering', 'salary': 105000,'years': 8},
#     {'name': 'Dave',  'dept': 'Marketing',   'salary': 68000, 'years': 2},
#     {'name': 'Eve',   'dept': 'Engineering', 'salary': 88000, 'years': 4},
#     {'name': 'Frank', 'dept': 'HR',          'salary': 65000, 'years': 6},
#     {'name': 'Grace', 'dept': 'HR',          'salary': 70000, 'years': 7},
# ]
# ```
#
# **Tasks:**
# 1. List the names of all Engineering employees
# 2. Find the average salary across all employees
# 3. Find the highest-paid employee (name and salary)
# 4. List all employees with more than 4 years of experience
# 5. Count how many employees are in each department (return a dictionary)

# %%
# Your code here
employees = [
    {'name': 'Alice', 'dept': 'Engineering', 'salary': 95000, 'years': 5},
    {'name': 'Bob',   'dept': 'Marketing',   'salary': 72000, 'years': 3},
    {'name': 'Carol', 'dept': 'Engineering', 'salary': 105000,'years': 8},
    {'name': 'Dave',  'dept': 'Marketing',   'salary': 68000, 'years': 2},
    {'name': 'Eve',   'dept': 'Engineering', 'salary': 88000, 'years': 4},
    {'name': 'Frank', 'dept': 'HR',          'salary': 65000, 'years': 6},
    {'name': 'Grace', 'dept': 'HR',          'salary': 70000, 'years': 7},
]

# 1. Engineering employees

# 2. Average salary

# 3. Highest paid

# 4. More than 4 years experience

# 5. Count by department

# %% [markdown]
# ---
#
# ### Exercise 5 — Challenge 🌟
#
# Write a function `grade_report(students)` that takes a list of student dictionaries (each with `name` and `score` keys) and:
# 1. Assigns a letter grade to each student (A/B/C/D/F)
# 2. Returns a **formatted report** as a string, like:
#
# ```
# ====== GRADE REPORT ======
# Alice       88   B
# Bob         72   C
# Charlie     45   F
# --------------------------
# Class average: 68.3
# Pass rate:     66.7%
# Top student:   Alice (88)
# ==========================
# ```
#
# > Passing is score ≥ 60

# %%
# Write grade_report() function

def assign_grade(score):
    # Copy from lecture or rewrite
    pass

def grade_report(students):
    # Your implementation
    pass

# Test data
test_students = [
    {'name': 'Alice',   'score': 88},
    {'name': 'Bob',     'score': 72},
    {'name': 'Charlie', 'score': 45},
    {'name': 'Diana',   'score': 95},
    {'name': 'Eve',     'score': 63},
    {'name': 'Frank',   'score': 38},
]

print(grade_report(test_students))

# %% [markdown]
# ---
#
# ## ✅ All Done!
#
# Check your answers by running each cell. If you're stuck:
# 1. Re-read the lecture notebook
# 2. Google the error message
# 3. Ask your instructor
#
# **Score yourself:** 5 exercises × 20 points = 100 points
