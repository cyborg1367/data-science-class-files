# %% [markdown]
# # 📝 Session 2 — Exercises: NumPy & Pandas
# ## Module 1: Basics of Data Science
#
# **Dataset:** Titanic | **Library:** NumPy, Pandas
#
# ---
#
# > Complete all exercises. Run the setup cell first!
#
# ---

# %%
import numpy as np
import pandas as pd
import urllib.request, os

# Load Titanic
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
if not os.path.exists('titanic.csv'):
    urllib.request.urlretrieve(url, 'titanic.csv')
df = pd.read_csv('titanic.csv')
print(f'Titanic loaded: {df.shape}')
df.head(3)

# %% [markdown]
# ---
#
# ### Exercise 1 — NumPy Basics (Basic)
#
# Create a NumPy array of all integers from **1 to 50** (inclusive).
#
# **Tasks:**
# 1. Create the array using `np.arange()`
# 2. Print the mean, median, standard deviation, and variance
# 3. Extract all values **divisible by 7** using boolean indexing
# 4. Compute the element-wise square root of the whole array (use `np.sqrt`)
# 5. Reshape the array into a **5×10 matrix** and print its shape

# %%
# Your code here

# 1. Create array 1..50

# 2. Stats

# 3. Divisible by 7

# 4. Square root

# 5. Reshape

# %% [markdown]
# ---
#
# ### Exercise 2 — Pandas Exploration (Basic)
#
# Using the Titanic dataset:
#
# 1. How many rows and columns does it have?
# 2. Which columns have missing values, and how many?
# 3. What is the data type of each column?
# 4. What is the overall survival rate (in %)?
# 5. How many unique values does the `Embarked` column have?

# %%
# Your code here
# (use the df loaded above)

# 1. Shape

# 2. Missing values

# 3. Data types

# 4. Survival rate

# 5. Embarked unique values

# %% [markdown]
# ---
#
# ### Exercise 3 — Filtering & Selection (Intermediate)
#
# 1. Select only the columns: `Name`, `Age`, `Sex`, `Survived`, `Pclass`
# 2. Filter passengers who **survived** AND were in **3rd class**
# 3. Find the **youngest** and **oldest** passengers who survived
# 4. List all passengers who paid more than **£200** for their ticket (show Name + Fare + Pclass)
# 5. Find passengers whose age is **unknown** (missing)

# %%
# Your code here

# 1. Select columns

# 2. Survived AND 3rd class

# 3. Youngest and oldest survivors

# 4. Fare > 200

# 5. Missing age

# %% [markdown]
# ---
#
# ### Exercise 4 — GroupBy & Analysis (Intermediate)
#
# Answer the following questions using `groupby()`:
#
# 1. What is the **survival rate by sex**? (as a percentage)
# 2. What is the **average age** for each passenger class?
# 3. What is the **survival count and rate** broken down by **both Pclass and Sex**?
# 4. What was the **average fare** paid by survivors vs non-survivors?
# 5. Which **embarkation port** had the **highest survival rate**?

# %%
# Your code here

# 1. Survival rate by sex (%)

# 2. Average age by class

# 3. Survival by Pclass AND Sex

# 4. Avg fare: survivors vs non-survivors

# 5. Survival rate by embarkation port

# %% [markdown]
# ---
#
# ### Exercise 5 — Feature Engineering & Summary (Challenge 🌟)
#
# Create a complete mini-analysis of the Titanic dataset:
#
# 1. Create a new column `Title` by extracting the title from `Name` (Mr, Mrs, Miss, Master, etc.)
#    - Hint: `df['Name'].str.extract(r' ([A-Za-z]+)\.', expand=False)`
# 2. Show the survival rate for each title
# 3. Create a `Deck` column from the first letter of `Cabin` (where available)
# 4. Create a `FamilySize` column = `SibSp + Parch + 1`
# 5. Write a summary paragraph (as a markdown cell) with your top 3 findings from this dataset
#
# > **Tip:** For task 5, add a new markdown cell below your code.

# %%
# Your code here

# 1. Extract Title
df['Title'] = df['Name'].str.extract(r' ([A-Za-z]+)\.', expand=False)
print(df['Title'].value_counts())

# 2. Survival rate by Title

# 3. Deck column

# 4. FamilySize

# 5. Your analysis (add a markdown cell below!)

# %% [markdown]
# ### My Findings
#
# *(Replace this with your own analysis after completing Exercise 5)*
#
# **Finding 1:**
#
# **Finding 2:**
#
# **Finding 3:**

# %% [markdown]
# ---
#
# ## ✅ All Done!
#
# **Bonus Challenge:**
# Load a completely different dataset from Kaggle or a CSV of your choice and run the same basic exploration (shape, info, describe, missing values, one groupby).
