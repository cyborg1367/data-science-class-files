# %% [markdown]
# <div dir="rtl">
#
# # تمرین کلاسی Pandas — علوم داده
#
# این نوت‌بوک برای تمرین مباحث پایه و کاربردی Pandas طراحی شده است.
#
# ### قوانین
# - پاسخ هر تمرین را در **Code Cell خالی زیر همان تمرین** بنویسید.
# - تمام تمرین‌ها را با Pandas حل کنید.
# - تا جای ممکن از loop استفاده نکنید.
# - در بخش Cleaning ابتدا وضعیت داده را بررسی کنید و سپس تغییرات را اعمال کنید.
# - هدف، حل مسئله با DataFrame است؛ نه حفظ کردن دستورها.
#
# ### مسیر تمرین
# 1. شناخت DataFrame
# 2. انتخاب ستون‌ها
# 3. انتخاب سطر و Slicing
# 4. Filtering
# 5. مرتب‌سازی و ساخت ستون
# 6. Pandas و NumPy
# 7. Missing Values
# 8. Data Cleaning مقدماتی
# 9. آمار توصیفی و GroupBy
# 10. چالش نهایی
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ## داده‌ی تمرین
#
# در تمام بخش‌ها از DataFrame زیر استفاده می‌کنیم. داده عمداً چند مشکل کوچک مانند Missing Value، شیوه‌های متفاوت نوشتن نام شهر و داده‌ی متنی نامناسب دارد.
#
# ابتدا سلول زیر را اجرا کنید.
#
# </div>

# %%
import numpy as np
import pandas as pd

students = pd.DataFrame({
    "student_id": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112],
    "name": [" Ali ", "Sara", "Reza", "Neda", "Amir", "Mina", "Pouya", "Leila", "Arman", "Sahar", "Kian", "Sara"],
    "age": [22, 24, 21, 23, np.nan, 22, 26, 25, 20, 24, 27, 24],
    "city": ["Tehran", "shiraz", "Tehran", "Tabriz", "Shiraz", None, "tehran", "Mashhad", "TEHRAN", "Tabriz", "Shiraz", "shiraz"],
    "python_score": [17.5, 19.0, 14.0, 18.0, 15.5, 20.0, 13.0, 16.5, 18.5, np.nan, 12.0, 19.0],
    "statistics_score": [16.0, 18.5, 15.0, 17.0, 14.0, 19.0, 12.5, 16.0, 17.5, 15.5, np.nan, 18.5],
    "project_score": [18.0, 19.5, 13.5, 17.0, 16.0, 20.0, 14.0, 15.5, 19.0, 16.5, 11.5, 19.5],
    "attendance": [92, 98, 75, 88, 80, 100, 68, 85, 95, 90, 72, 98],
    "discount": ["10", "5", "none", "0", "5", None, "none", "10", "0", "5", "15", "5"]
})

students

# %% [markdown]
# <div dir="rtl">
#
# # بخش 1 — شناخت اولیه‌ی DataFrame
#
# ### تمرین 1
# ابعاد DataFrame را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 2
# نام تمام ستون‌های DataFrame را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 3
# نوع داده‌ی هر ستون را بررسی کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 4
# پنج سطر اول DataFrame را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 5
# سه سطر آخر DataFrame را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 6
# اطلاعات کلی DataFrame را با متدی مناسب مشاهده کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # بخش 2 — انتخاب ستون‌ها
#
# ### تمرین 7
# فقط ستون `name` را انتخاب و نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 8
# ستون‌های `name`، `city` و `python_score` را انتخاب کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 9
# بررسی کنید خروجی انتخاب یک ستون چه نوع شیئی در Pandas است.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # بخش 3 — انتخاب سطرها و Slicing
#
# ### تمرین 10
# اولین سطر DataFrame را با `iloc` نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 11
# چهار سطر اول DataFrame را با `iloc` نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 12
# سطرهای موقعیت 2 تا 5 و فقط سه ستون اول DataFrame را انتخاب کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 13
# با `loc`، سطرهای index شماره 3 تا 6 و ستون‌های `name` و `project_score` را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 14
# ستون `student_id` را به عنوان index یک DataFrame جدید با نام `students_by_id` قرار دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 15
# از `students_by_id` اطلاعات دانشجوی دارای شناسه‌ی 105 را با `loc` نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # بخش 4 — Filtering
#
# ### تمرین 16
# تمام دانشجوهایی را نمایش دهید که نمره‌ی Python آن‌ها بیشتر یا مساوی 17 است.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 17
# دانشجوهایی را نمایش دهید که سن آن‌ها بیشتر از 23 سال است.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 18
# دانشجوهایی را پیدا کنید که هم نمره‌ی Python آن‌ها حداقل 16 و هم نمره‌ی Statistics آن‌ها حداقل 16 است.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 19
# دانشجوهایی را نمایش دهید که شهر آن‌ها دقیقاً `Tehran` است.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 20
# دانشجوهایی را نمایش دهید که شهر آن‌ها یکی از `Tehran`، `Shiraz` یا `Tabriz` است.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 21
# دانشجوهایی با نمره‌ی پروژه بیشتر از 16 را پیدا کنید و فقط `name`، `city` و `project_score` را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # بخش 5 — مرتب‌سازی و ساخت ستون‌های جدید
#
# ### تمرین 22
# DataFrame را بر اساس `project_score` از بیشترین به کمترین مرتب کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 23
# سه دانشجوی دارای بالاترین نمره‌ی پروژه را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 24
# یک کپی از DataFrame با نام `df` بسازید تا از این بخش به بعد تغییرات روی آن انجام شود.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 25
# در `df` ستونی به نام `average_score` بسازید که میانگین `python_score`، `statistics_score` و `project_score` باشد.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 26
# یک ستون `passed` بسازید که برای `average_score >= 14` مقدار True و برای بقیه False باشد.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 27
# یک ستون `python_percent` بسازید که نمره Python را از مقیاس 20 به درصد تبدیل کند.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 28
# DataFrame را بر اساس `average_score` از بیشترین به کمترین مرتب کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # بخش 6 — Pandas و NumPy
#
# ### تمرین 29
# ستون‌های `age`، `python_score` و `statistics_score` را به NumPy Array تبدیل کنید و در `arr` قرار دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 30
# نوع و shape آرایه‌ی `arr` را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 31
# فقط ستون `project_score` را به NumPy Array تبدیل کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # بخش 7 — Missing Values
#
# ### تمرین 32
# تعداد Missing Valueهای هر ستون را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 33
# تمام سطرهایی را نمایش دهید که `age` در آن‌ها Missing است.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 34
# Missingهای `age` را با median همین ستون پر کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 35
# Missingهای `city` را با پرتکرارترین مقدار این ستون پر کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 36
# Missingهای `python_score` و `statistics_score` را با median هر ستون پر کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # بخش 8 — Data Cleaning مقدماتی
#
# ### تمرین 37
# فاصله‌های اضافی ابتدا و انتهای مقادیر ستون `name` را حذف کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 38
# نحوه‌ی نوشتن نام شهرها را یکدست کنید؛ حرف اول بزرگ و بقیه کوچک باشد.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 39
# در ستون `discount` مقدار متنی `none` را به Missing Value تبدیل کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 40
# ستون `discount` را عددی کنید؛ مقادیر غیرقابل تبدیل باید Missing شوند.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 41
# Missingهای `discount` را با median این ستون پر کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 42
# بررسی کنید آیا سطر کاملاً تکراری وجود دارد و تعداد آن‌ها را نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 43
# بررسی کنید آیا بر اساس ترکیب `name`، `city` و `project_score` رکورد تکراری وجود دارد.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # بخش 9 — آمار توصیفی و GroupBy
#
# ### تمرین 44
# میانگین، میانه، انحراف معیار و واریانس `average_score` را محاسبه کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 45
# تعداد دانشجوهای هر شهر را محاسبه کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 46
# میانگین `average_score` دانشجوها را برای هر شهر محاسبه کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 47
# برای هر شهر، تعداد دانشجو، میانگین و بیشترین `average_score` را محاسبه کنید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # بخش 10 — چالش نهایی
#
# ### تمرین 48
# DataFrame جدیدی به نام `top_students` بسازید که:
# - `average_score >= 16`
# - `attendance >= 85`
# - فقط ستون‌های `student_id`، `name`، `city`، `average_score` و `attendance`
# - مرتب‌شده بر اساس `average_score` از بیشترین به کمترین باشد.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# ### تمرین 49 — چالش اضافه
# ستون `final_score` بسازید:
# - 30٪ Python
# - 30٪ Statistics
# - 40٪ Project
#
# سپس 5 دانشجوی برتر را بر اساس آن نمایش دهید.
#
# </div>

# %% [markdown]
# <div dir="rtl">
#
# # پایان تمرین
#
# تمام Code Cellها را اجرا کنید و مطمئن شوید پاسخ هر تمرین خروجی مورد انتظار همان سؤال را تولید می‌کند.
#
# </div>
